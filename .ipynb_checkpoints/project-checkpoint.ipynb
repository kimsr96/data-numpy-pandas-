# %%
import requests # 크롤링에 사용하는 패키지
from bs4 import BeautifulSoup # html 변환에 사용함
import pandas as pd
import re

url = 'https://movie.naver.com/movie/running/premovie.nhn'
response = requests.get(url).text
html = BeautifulSoup(response, 'html.parser')

movies = html.find_all("dl", attrs={"class":"lst_dsc"})

title_list = []
link_list = []
up_list = []
down_list = []
genre_list = []
runningTime_list = []
releaseDate_list = []
for movie in movies:
    genres =[]
    if movie.find("dl", attrs={"class":"info_exp"}):
        title = movie.find("a").get_text().strip()
        link= movie.find("a")["href"]
        up = movie.find_all('em', attrs={"class":"exp_cnt"})[0].get_text()      
        down = movie.find_all('em', attrs={"class":"exp_cnt"})[1].get_text()
        genre = movie.find('span', attrs={"class":"link_txt"}).find_all('a', limit=3)
        
        for i in genre:
            genres.append(i.get_text())
        

        runningTime = movie.find('dl', attrs={"class":"info_txt1"}).find('dd')
        print(runningTime)
        p = re.compile("분$")
        m = p.match(runningTime)
        print(m.group())
 
        title_list.append(title)
        link_list.append(f"https://movie.naver.com"+link)
        up_list.append(up)
        down_list.append(down)
        genre_list.append(genres)
        runningTime_list.append(runningTime)


            
df = pd.DataFrame(columns=['title', 'link', 'up', 'down', 'genre'])
df['title']= title_list
df['link']= link_list
df['up']= up_list
df['down']=down_list
df['genre'] = genre_list
df['runningTime']= runningTime_list

# df.to_csv("movie.csv", mode='w')
# Out:
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=4">공포</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								94분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.08 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								114분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								103분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								113분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								88분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=12">가족</a><!-- N=a:sol.genre,r:3 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=2">판타지</a><!-- N=a:sol.genre,r:4 -->
# </span>
# <span class="split">|</span>
# 								80분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								78분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=13">미스터리</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								91분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								80분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=11">코미디</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								98분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=16">범죄</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								99분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								92분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=16">범죄</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								115분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.11 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=29">공연실황</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								83분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.11 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								107분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.17 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=13">미스터리</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								112분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.17 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=11">코미디</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								105분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.17 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=2">판타지</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								115분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.17 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=18">SF</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								104분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.17 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								101분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.18 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								90분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.18 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								107분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.18 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								59분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.18 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=16">범죄</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								118분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.19 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=16">범죄</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								99분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								97분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								120분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								79분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								90분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=17">뮤지컬</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=29">공연실황</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								148분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								112분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								100분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=18">SF</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								103분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=16">범죄</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								114분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.24 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# </span>
#
#
#
#
#
#
#
#
#
# 								101분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.25 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=2">판타지</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								89분
#
#
#
# 								<span class="split">|</span>
# 								2021.02.25 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								100분
#
#
#
# 								<span class="split">|</span>
# 								2021.02 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=18">SF</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								96분
#
#
#
# 								<span class="split">|</span>
# 								2021.02 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=11">코미디</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								83분
#
#
#
# 								<span class="split">|</span>
# 								2021.02 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=16">범죄</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								93분
#
#
#
# 								<span class="split">|</span>
# 								2021.02 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=18">SF</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								82분
#
#
#
# 								<span class="split">|</span>
# 								2021.02 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								86분
#
#
#
# 								<span class="split">|</span>
# 								2021.02 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								121분
#
#
#
# 								<span class="split">|</span>
# 								2021.02 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								115분
#
#
#
# 								<span class="split">|</span>
# 								2021.03.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=12">가족</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								108분
#
#
#
# 								<span class="split">|</span>
# 								2021.03.04 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								89분
#
#
#
# 								<span class="split">|</span>
# 								2021.03.04 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								127분
#
#
#
# 								<span class="split">|</span>
# 								2021.03.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=2">판타지</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								118분
#
#
#
# 								<span class="split">|</span>
# 								2021.03.11 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								172분
#
#
#
# 								<span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								108분
#
#
#
# 								<span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=15">애니메이션</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								86분
#
#
#
# 								<span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=12">가족</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								99분
#
#
#
# 								<span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=5">멜로/로맨스</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								123분
#
#
#
# 								<span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=14">전쟁</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								83분
#
#
#
# 								<span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								104분
#
#
#
# 								<span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=18">SF</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								90분
#
#
#
# 								<span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								97분
#
#
#
# 								<span class="split">|</span>
# 								2021.03 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=16">범죄</a><!-- N=a:sol.genre,r:2 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=7">스릴러</a><!-- N=a:sol.genre,r:3 -->
# </span>
# <span class="split">|</span>
# 								101분
#
#
#
# 								<span class="split">|</span>
# 								2021.04.08 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								2021.05 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->
# </span>
# <span class="split">|</span>
# 								2021.10 개봉
#
#
# 						</dd>
# <dd>
# <span class="link_txt">
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:sol.genre,r:1 -->,
#
# 									<a href="/movie/sdb/browsing/bmovie.nhn?genre=6">모험</a><!-- N=a:sol.genre,r:2 -->
# </span>
# <span class="split">|</span>
# 								2022.06.10 개봉
#
#
# 						</dd>

# %%
# !pip3 install re
# Out:
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re

# %%
df
# Out:
#               title                                               link     up  \
# 0           데스 오브 미  https://movie.naver.com/movie/bi/mi/basic.nhn?...     17
# 1              새해전야  https://movie.naver.com/movie/bi/mi/basic.nhn?...   6760
# 2            몬스터 헌터  https://movie.naver.com/movie/bi/mi/basic.nhn?...    384
# 3                아이  https://movie.naver.com/movie/bi/mi/basic.nhn?...    830
# 4          살아남은 사람들  https://movie.naver.com/movie/bi/mi/basic.nhn?...     60
# ..              ...                                                ...    ...
# 57         피넛 버터 팔콘  https://movie.naver.com/movie/bi/mi/basic.nhn?...     37
# 58        추룡 2 : 패왕  https://movie.naver.com/movie/bi/mi/basic.nhn?...      5
# 59  분노의 질주: 더 얼티메이트  https://movie.naver.com/movie/bi/mi/basic.nhn?...  10668
# 60    007 노 타임 투 다이  https://movie.naver.com/movie/bi/mi/basic.nhn?...   5232
# 61     쥬라기 월드: 도미니언  https://movie.naver.com/movie/bi/mi/basic.nhn?...   4673
#
#    down          genre                                        runningTime
# 0     2      [공포, 스릴러]  \n\n공포, \r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
# 1   434       [멜로/로맨스]  \n\n멜로/로맨스\n\n|\r\n\t\t\t\t\t\t\t\t114분\r\n\t\...
# 2    45       [액션, 모험]  \n\n액션, \r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
# 3    79          [드라마]  \n\n드라마\n\n|\r\n\t\t\t\t\t\t\t\t113분\r\n\t\t\t...
# 4     1  [드라마, 멜로/로맨스]  \n\n드라마, \r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\...
# ..  ...            ...                                                ...
# 57    4          [드라마]  \n\n드라마\n\n|\r\n\t\t\t\t\t\t\t\t97분\r\n\t\t\t\...
# 58    3  [액션, 범죄, 스릴러]  \n\n액션, \r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
# 59  293           [액션]  \n\n액션\n\n|\r\n\t\t\t\t\t\t\t\t2021.05 개봉\r\n\...
# 60  188           [액션]  \n\n액션\n\n|\r\n\t\t\t\t\t\t\t\t2021.10 개봉\r\n\...
# 61  112       [액션, 모험]  \n\n액션, \r\n\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t...
#
# [62 rows x 6 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [title, link, up, down]
# Index: []
