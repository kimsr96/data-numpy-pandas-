# %% [markdown]
# # **강사소개**

# %% [markdown]
# ## 변치웅 강사
#     고려대학교 경제학과 학사
#     (전)삼성생명 운용팀
#     (전)유쾌한형제(신랑신부모여, 카넥트, Naver car cp)
#     KTH 올레tv 플랫폼 기획자
#     패스트캠퍼스 데이터 사이언스스쿨 5기 수료
#     (현) fitror.com 대표

# %% [markdown]
# ## Doing
#     딥러닝 알고리즘을 활용한 주식 자동화 트레이딩 시스템 개발
#
#     패스트 캠퍼스 기업강의

# %% [markdown]
# ## Done
#     SK네트웍스, KB카드, 신한금융그룹, 신한생명,
#     미래에셋금융그룹, 미래에셋생명, 현대자동차
#     신한카드, 미래에셋생명, 현대모비스 프로젝트 기업강의 참여
#
#     IFRS 채권 현재가치 산출 프로그램 개발
#
#     상기 기업체 프로젝트 약 80여건 컨설팅

# %% [markdown]
# ## 우리는 지금 어디?
# ![kruger.png](data:image/png;base64,...)

# %% [markdown]
# # **과정소개**
# ## **파이썬을 통한 데이터 분석가 양성 과정**
#
#
# 1.   오리엔테이션
# 2.   파이썬 기초프로그래밍
# 3.   크롤링
# 4.   라이브러리 & 시각화
# 5.   프로젝트 수행

# %% [markdown]
# # 1. **컴퓨터의 구조**
#
# 1.   입력
# 2.   저장
# 3.   연산
# 4.   출력

# %% [markdown]
# # 2. **운영체제**
#
#
# 1.   Windows
# 2.   Linux
# 3.   안드로이드
# 4.   iOS

# %% [markdown]
# # 3. **프로그램이란?**
#     코드? 컴퓨터가 알아들을 수 있는 명령들의 집합
#     코딩을 한다, 코드를 짠다 곧 컴퓨터가 알아들을 수 있는 명령어를 작성하는 행위
#     컴퓨터에게 지시를 하기 위한 수단
#
#     프로그램이란? 컴퓨터에게 작업을 지시하는 코드의 집합
#     프로그램으로 만들 수 있는 작업은?
